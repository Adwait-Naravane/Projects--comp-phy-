# %% [markdown]
# <a href="https://colab.research.google.com/github/Adwait-Naravane/Projects--comp-phy-/blob/Computational-Quantum-mech/Quantum_Direct_Matrix.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.linalg import eigh_tridiagonal
from numba import jit

# %%
N = 10000
dy = 1/N
y = np.linspace(0, 1, N+1)

# %%
@jit(nopython = True)
def V(y):
    return -1000*np.exp(-(y-0.5)**2/(2*0.005**2))

d = 1/dy**2 + V(y)[1:-1]
e = -1/(2*dy**2) * np.ones(len(d)-1)
w, v = eigh_tridiagonal(d, e)

# %%
plt.style.use("dark_background")
plt.figure(figsize=(10,5))
plt.plot(y[1:-1], v.T[0])
plt.plot(y[1:-1], v.T[1])
plt.plot(y[1:-1], v.T[2])
plt.plot(y[1:-1], v.T[3])
plt.title('Eigenstates', fontsize=30)
plt.ylabel('$\psi$', fontsize=25)
plt.xlabel('$x/L$', fontsize=25)
# Out:
# Text(0.5, 0, '$x/L$')

# %%
plt.bar(np.arange(0, 10, 1), w[0:10])
plt.title('Energy eigenvalues (dimensionless)')
plt.ylabel('Energy')
plt.xlabel('order')
# Out:
# Text(0.5, 0, 'order')
